# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from PIL import Image

# %%
 pic=Image.open(r'C:\Users\th\Desktop\cv\cover.png')

# %%
 pic
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1500x600 at 0x1E0456FBE0>

# %%
type(pic)
# Out:
# PIL.PngImagePlugin.PngImageFile

# %%
pic_arr=np.asarray(pic)

# %%
pic_arr.shape
# Out:
# (600, 1500, 4)

# %%
plt.imshow(pic_arr)

# %%
pic_red=pic_arr.copy()

# %%
plt.imshow(pic_red)

# %%
pic_red[:,:,0]=0
