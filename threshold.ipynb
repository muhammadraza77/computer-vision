# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

######same size images################
img2=cv2.imread("cover.png",0)

plt.imshow(img2,'gray')
img2
# Out:
# array([[255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        ...,
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255],
#        [255, 255, 255, ..., 255, 255, 255]], dtype=uint8)

# %%
res,th1=cv2.threshold(img2,254,255,cv2.THRESH_BINARY)
th1=cv2.adaptiveThreshold(img2,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,17,8)

plt.imshow(th1,'gray')
