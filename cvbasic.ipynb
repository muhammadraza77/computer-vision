# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2

# %%
img=cv2.imread('cover.png')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
plt.imshow(img)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
img=cv2.imread('cover.png',cv2.IMREAD_GRAYSCALE)

# %%
img.shape
# Out:
# (600, 1500)

# %%
nimg=cv2.flip(img,0)

# %%
cv2.imwrite("cover1.png",nimg)
# Out:
# True

# %%
fig=plt.figure(figsize=(10,8))
ax=fig.add_subplot(111)
ax.imshow(img)
